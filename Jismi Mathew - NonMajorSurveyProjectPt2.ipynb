# %% [markdown]
# ## Non-Majors Survey Results

# %% [markdown]
# Jismi Mathew

# %% [markdown]
# 10/08/2025

# %% [markdown]
# Purpose: Explore Non-Majors Survey dataset using Python, and perform data cleaning using pandas.

# %%
import pandas as pd

# %%
datafile = 'Non-Majors_Survey_Results-Fall 2024.csv'
df = pd.read_csv(datafile, parse_dates=True)

# %% [markdown]
# Explore Data:

# %%
df.describe()
# Out:
#        On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?
# count                                          92.000000
# mean                                            2.576087
# std                                             1.131310
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             5.000000

# %%
df.columns
# Out:
# Index(['Timestamp', 'Which course are you currently enrolled in?',
#        'What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]',
#        'What motivated you to seek a computing class at CCM? [To keep current in computing skills]',
#        'What motivated you to seek a computing class at CCM? [Career Advancement]',
#        'What motivated you to seek a computing class at CCM? [Career Change]',
#        'What motivated you to seek a computing class at CCM? [Professional Development]',
#        'What motivated you to seek a computing class at CCM? [Job Displacement]',
#        'What motivated you to seek a computing class at CCM? [Relocation]',
#        'What motivated you to seek a computing class at CCM? [IT Industry Certifications]',
#        'What motivated you to seek a computing class at CCM? [Financial]',
#        'What motivated you to seek a computing class at CCM? [Personal Enrichment]',
# ...

# %%
df.shape
# Out:
# (92, 71)

# %%
df.dtypes
# Out:
# Timestamp                                                                                                                                    object
# Which course are you currently enrolled in?                                                                                                  object
# What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]                                      object
# What motivated you to seek a computing class at CCM? [To keep current in computing skills]                                                   object
# What motivated you to seek a computing class at CCM? [Career Advancement]                                                                    object
#                                                                                                                                               ...
# ...

# %%
df.head(5)
# Out:
#                     Timestamp   Which course are you currently enrolled in?  \
# 0  2024/09/10 10:47:35 AM AST  CMP 126 Computer Technology and Applications
# 1  2024/09/10 11:00:05 AM AST  CMP 126 Computer Technology and Applications
# 2  2024/09/10 11:02:51 AM AST  CMP 126 Computer Technology and Applications
# 3  2024/09/10 11:05:25 AM AST  CMP 126 Computer Technology and Applications
# 4   2024/09/10 8:37:36 PM AST         CMP 101 Computer Information Literacy
#
#   What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   What motivated you to seek a computing class at CCM? [To keep current in computing skills]  \
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                      Timestamp   Which course are you currently enrolled in?  \
# 0   2024/09/10 10:47:35 AM AST  CMP 126 Computer Technology and Applications
# 1   2024/09/10 11:00:05 AM AST  CMP 126 Computer Technology and Applications
# 2   2024/09/10 11:02:51 AM AST  CMP 126 Computer Technology and Applications
# 3   2024/09/10 11:05:25 AM AST  CMP 126 Computer Technology and Applications
# 4    2024/09/10 8:37:36 PM AST         CMP 101 Computer Information Literacy
# ..                         ...                                           ...
# 87  2024/09/20 10:55:34 PM AST         CMP 101 Computer Information Literacy
# 88  2024/09/20 11:02:45 PM AST  CMP 126 Computer Technology and Applications
# 89  2024/09/20 11:07:16 PM AST  CMP 126 Computer Technology and Applications
# 90   2024/09/21 5:06:23 PM AST         CMP 101 Computer Information Literacy
# 91  2024/09/22 10:08:19 PM AST  CMP 126 Computer Technology and Applications
#
# ...

# %%
df.sample()
# Out:
#                     Timestamp   Which course are you currently enrolled in?  \
# 1  2024/09/10 11:00:05 AM AST  CMP 126 Computer Technology and Applications
#
#   What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]  \
# 1                                                Yes
#
#   What motivated you to seek a computing class at CCM? [To keep current in computing skills]  \
# 1                                                Yes
#
#   What motivated you to seek a computing class at CCM? [Career Advancement]  \
# 1                                                Yes
#
#   What motivated you to seek a computing class at CCM? [Career Change]  \
# 1                                                 No
#
#   What motivated you to seek a computing class at CCM? [Professional Development]  \
# 1                                                Yes
#
#   What motivated you to seek a computing class at CCM? [Job Displacement]  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                      Timestamp   Which course are you currently enrolled in?  \
# 0   2024/09/10 10:47:35 AM AST  CMP 126 Computer Technology and Applications
# 1   2024/09/10 11:00:05 AM AST  CMP 126 Computer Technology and Applications
# 2   2024/09/10 11:02:51 AM AST  CMP 126 Computer Technology and Applications
# 3   2024/09/10 11:05:25 AM AST  CMP 126 Computer Technology and Applications
# 4    2024/09/10 8:37:36 PM AST         CMP 101 Computer Information Literacy
# ..                         ...                                           ...
# 87  2024/09/20 10:55:34 PM AST         CMP 101 Computer Information Literacy
# 88  2024/09/20 11:02:45 PM AST  CMP 126 Computer Technology and Applications
# 89  2024/09/20 11:07:16 PM AST  CMP 126 Computer Technology and Applications
# 90   2024/09/21 5:06:23 PM AST         CMP 101 Computer Information Literacy
# 91  2024/09/22 10:08:19 PM AST  CMP 126 Computer Technology and Applications
#
# ...

# %% [markdown]
# Clean Data:

# %% [markdown]
# Show Data before changes:

# %%
df.head()
# Out:
#                     Timestamp   Which course are you currently enrolled in?  \
# 0  2024/09/10 10:47:35 AM AST  CMP 126 Computer Technology and Applications
# 1  2024/09/10 11:00:05 AM AST  CMP 126 Computer Technology and Applications
# 2  2024/09/10 11:02:51 AM AST  CMP 126 Computer Technology and Applications
# 3  2024/09/10 11:05:25 AM AST  CMP 126 Computer Technology and Applications
# 4   2024/09/10 8:37:36 PM AST         CMP 101 Computer Information Literacy
#
#   What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   What motivated you to seek a computing class at CCM? [To keep current in computing skills]  \
# ...

# %%
# make all column names lowercase and replace spaces and punctuation with underscores
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_", regex=False)
      .str.replace("’", "", regex=False)
      .str.replace("'", "", regex=False)
      .str.replace("?", "", regex=False)
      .str.replace("&", "and", regex=False)
      .str.replace("/", "_", regex=False)
      .str.replace(",", "", regex=False)
      .str.replace("[", "", regex=False)
      .str.replace("]", "", regex=False)
      .str.replace("(", "", regex=False)
      .str.replace(")", "", regex=False)
      .str.replace("__", "_", regex=False)
      .str.strip("_")
)

# %%
df.head()
# Out:
#                     timestamp    which_course_are_you_currently_enrolled_in  \
# 0  2024/09/10 10:47:35 AM AST  CMP 126 Computer Technology and Applications
# 1  2024/09/10 11:00:05 AM AST  CMP 126 Computer Technology and Applications
# 2  2024/09/10 11:02:51 AM AST  CMP 126 Computer Technology and Applications
# 3  2024/09/10 11:05:25 AM AST  CMP 126 Computer Technology and Applications
# 4   2024/09/10 8:37:36 PM AST         CMP 101 Computer Information Literacy
#
#   what_motivated_you_to_seek_a_computing_class_at_ccm_its_a_required_class_for_the_degree_im_seeking  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   what_motivated_you_to_seek_a_computing_class_at_ccm_to_keep_current_in_computing_skills  \
# ...

# %%
# rename the useful columns to shorter names
df.rename(columns={
    # Basic
    "which_course_are_you_currently_enrolled_in": "course",
    "on_a_scale_of_1_to_5_with_1_being_not_at_all_interested_and_5_being_extremely_interested_how_interested_are_you_taking_more_courses_in_computer_science_information_technology_or_game_development?": "interest",
    "race_ethnicity": "race",

    # Motivation questions
    "what_motivated_you_to_seek_a_computing_class_at_ccm_its_a_required_class_for_the_degree_im_seeking": "motivation_required_course",
    "what_motivated_you_to_seek_a_computing_class_at_ccm_to_keep_current_in_computing_skills": "motivation_keep_current",
    "what_motivated_you_to_seek_a_computing_class_at_ccm_career_advancement": "motivation_career_advancement",
    "what_motivated_you_to_seek_a_computing_class_at_ccm_career_change": "motivation_career_change",
    "what_motivated_you_to_seek_a_computing_class_at_ccm_professional_development": "motivation_prof_dev",
    "what_motivated_you_to_seek_a_computing_class_at_ccm_job_displacement": "motivation_job_displacement",
    "what_motivated_you_to_seek_a_computing_class_at_ccm_relocation": "motivation_relocation",
    "what_motivated_you_to_seek_a_computing_class_at_ccm_it_industry_certifications": "motivation_it_certifications",
    "what_motivated_you_to_seek_a_computing_class_at_ccm_financial": "motivation_financial",
    "what_motivated_you_to_seek_a_computing_class_at_ccm_personal_enrichment": "motivation_enrichment",
    "what_motivated_you_to_seek_a_computing_class_at_ccm_curiosity": "motivation_curiosity",

    # Interest (future courses)
    "if_you_answered_that_you_were_interested_in_taking_more_computing_classes_which_ones_interest_you_most_web_development": "interest_web_development",
    "if_you_answered_that_you_were_interested_in_taking_more_computing_classes_which_ones_interest_you_most_cybersecurity": "interest_cybersecurity",
    "if_you_answered_that_you_were_interested_in_taking_more_computing_classes_which_ones_interest_you_most_app_development": "interest_app_development",
    "if_you_answered_that_you_were_interested_in_taking_more_computing_classes_which_ones_interest_you_most_data_analytics": "interest_data_analytics",
    "if_you_answered_that_you_were_interested_in_taking_more_computing_classes_which_ones_interest_you_most_machine_learning_artificial_intelligence": "interest_ml_ai",
    "if_you_answered_that_you_were_interested_in_taking_more_computing_classes_which_ones_interest_you_most_computer_programming": "interest_programming",
    "if_you_answered_that_you_were_interested_in_taking_more_computing_classes_which_ones_interest_you_most_game_design": "interest_game_design",
    "if_you_answered_that_you_were_interested_in_taking_more_computing_classes_which_ones_interest_you_most_hardware_installation_and_repair": "interest_hardware_repair"
}, inplace=True)

# %% [markdown]
# Show data after column names changed

# %%
df.head()
# Out:
#                     timestamp                                        course  \
# 0  2024/09/10 10:47:35 AM AST  CMP 126 Computer Technology and Applications
# 1  2024/09/10 11:00:05 AM AST  CMP 126 Computer Technology and Applications
# 2  2024/09/10 11:02:51 AM AST  CMP 126 Computer Technology and Applications
# 3  2024/09/10 11:05:25 AM AST  CMP 126 Computer Technology and Applications
# 4   2024/09/10 8:37:36 PM AST         CMP 101 Computer Information Literacy
#
#   motivation_required_course motivation_keep_current  \
# 0                         No                     Yes
# 1                        Yes                     Yes
# 2                        Yes                     Yes
# 3                         No                     Yes
# 4                        Yes                     Yes
#
#   motivation_career_advancement motivation_career_change motivation_prof_dev  \
# 0                           Yes                      Yes                 Yes
# ...

# %% [markdown]
# Check if any duplicate rows:

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicates in this dataset

# %%
# clean text data
text_columns = ['course', 'gender', 'race', 'age']
for col in text_columns:
    if col in df.columns:
        df[col] = (df[col].astype(str).str.strip().str.lower().replace('nan', ''))

# %% [markdown]
# Display Cleaned Data:

# %%
display(df.head())
# Out:
#                     timestamp                                        course  \
# 0  2024/09/10 10:47:35 AM AST  cmp 126 computer technology and applications
# 1  2024/09/10 11:00:05 AM AST  cmp 126 computer technology and applications
# 2  2024/09/10 11:02:51 AM AST  cmp 126 computer technology and applications
# 3  2024/09/10 11:05:25 AM AST  cmp 126 computer technology and applications
# 4   2024/09/10 8:37:36 PM AST         cmp 101 computer information literacy
#
#   motivation_required_course motivation_keep_current  \
# 0                         No                     Yes
# 1                        Yes                     Yes
# 2                        Yes                     Yes
# 3                         No                     Yes
# 4                        Yes                     Yes
#
#   motivation_career_advancement motivation_career_change motivation_prof_dev  \
# 0                           Yes                      Yes                 Yes
# ...

# %%
df.to_csv("nonmajors_survey_cleaned_survey_data.csv", index=False)

# %% [markdown]
# ### Citations:

# %% [markdown]
# chatgpt.com
